# %%
import pandas as pd
import json

# %%
f = open('To Ajesh/schedule_anomalies.json', encoding="utf8")
data = json.load(f)
df = pd.DataFrame(data)

# %%
colu=df.columns
for col in colu:
    print(col+":")
    print(df[col][10])
    if col =="faceData":
        continue
    else:
        print("""
        
        
        
        -----------------------------------------------------------------------------------------------------------------
        
        
        """)
# Out:
# _id:
# {'$oid': '64cb890f9d060c40e62a1430'}
#
#
#
#
#         -----------------------------------------------------------------------------------------------------------------
#
#
#
# isDeleted:
# False
#
#
#
#
#         -----------------------------------------------------------------------------------------------------------------
#
#
#
# _institution_id:
# {'$oid': '5e5d0f1a15b4d600173d5692'}
#
#
#
#
#         -----------------------------------------------------------------------------------------------------------------
#
#
#
# scheduleId:
# {'$oid': '64cb74419d060cad50291587'}
#
#
#
#
#         -----------------------------------------------------------------------------------------------------------------
#
#
#
# studentId:
# {'$oid': '64afe7022fa3d1dd5df2ad6d'}
#
#
#
#
#         -----------------------------------------------------------------------------------------------------------------
#
#
#
# faceData:
# ...
# createdAt:
# {'$date': {'$numberLong': '1691060495074'}}
#
#
#
#
#         -----------------------------------------------------------------------------------------------------------------
#
#
#
# updatedAt:
# {'$date': {'$numberLong': '1691060495074'}}
#
#
#
#
#         -----------------------------------------------------------------------------------------------------------------
#
#
#
# __v:
# 0
#
#
#
#
#         -----------------------------------------------------------------------------------------------------------------
#
#
#
# pure:
# True
#
#
#
#
#         -----------------------------------------------------------------------------------------------------------------

# %%
df["_id"]=df["_id"].str.get('$oid')
df["_id"]
# Out:
# 0       64ca386a9d060c911323638b
# 1       64ca38af9d060c0e9123647e
# 2       64ca49759d060c4f7f24e228
# 3       64ca4b8e9d060cbacd254a4f
# 4       64ca4dbc9d060c07ae25b107
#                   ...
# 1196    6532332bbf6e74b13366a3ff
# 1197    6532334dbf6e74443766a409
# 1198    65323369bf6e74d7c966a439
# 1199    65325842bf6e746f2266ae1f
# 1200    65325a06bf6e7487d866b00c
# Name: _id, Length: 1201, dtype: object

# %%
df["isDeleted"]
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1196    False
# 1197    False
# 1198    False
# 1199    False
# 1200    False
# Name: isDeleted, Length: 1201, dtype: bool

# %%
df["_institution_id"]=df["_institution_id"].str.get('$oid')
df["_institution_id"]
# Out:
# 0       5e5d0f1a15b4d600173d5692
# 1       5e5d0f1a15b4d600173d5692
# 2       5e5d0f1a15b4d600173d5692
# 3       5e5d0f1a15b4d600173d5692
# 4       5e5d0f1a15b4d600173d5692
#                   ...
# 1196    5e5d0f1a15b4d600173d5692
# 1197    5e5d0f1a15b4d600173d5692
# 1198    5e5d0f1a15b4d600173d5692
# 1199    5e5d0f1a15b4d600173d5692
# 1200    5e5d0f1a15b4d600173d5692
# Name: _institution_id, Length: 1201, dtype: object

# %%
df["scheduleId"]=df["scheduleId"].str.get('$oid')
df["scheduleId"]
# Out:
# 0       64b67ad2e04b98b860e4678f
# 1       64b67ad2e04b98b860e4678f
# 2       64ca3c5b9d060c3ded23b6ff
# 3       64ca3c5b9d060c3ded23b6ff
# 4       64ca3c5b9d060c3ded23b6ff
#                   ...
# 1196    65322f58bf6e74c1ba66a234
# 1197    65322f58bf6e74c1ba66a234
# 1198    65322f58bf6e74c1ba66a234
# 1199    6532551abf6e74811f66ad61
# 1200    6532551abf6e74811f66ad61
# Name: scheduleId, Length: 1201, dtype: object

# %%
df["studentId"]=df["studentId"].str.get('$oid')
df["studentId"]
# Out:
# 0       649d8442e2cf07ec24d6b982
# 1       649d8442e2cf07ec24d6b982
# 2       61a61789b1723a7f23346f70
# 3       61a61789b1723a7f23346f70
# 4       61a61789b1723a7f23346f70
#                   ...
# 1196    62babe4b58e9580f791fc6a4
# 1197    62babe4b58e9580f791fc6a4
# 1198    62babe4b58e9580f791fc6a4
# 1199    62babe4b58e9580f791fc6a4
# 1200    60d06d968ff3991852c9bcc4
# Name: studentId, Length: 1201, dtype: object

# %%
df["createdAt"]=df["createdAt"].str.get('$date')
df["createdAt"]=df["createdAt"].str.get('$numberLong')
df['createdAt'] = pd.to_datetime(df['createdAt'], unit='ms').dt.strftime('%Y-%m-%d %H:%M:%S')
df['createdAt']
# Out:
# C:\Users\ajesh\AppData\Local\Temp\ipykernel_3364\3894669561.py:3: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   df['createdAt'] = pd.to_datetime(df['createdAt'], unit='ms').dt.strftime('%Y-%m-%d %H:%M:%S')
# 0       2023-08-02 11:04:49
# 1       2023-08-02 11:07:00
# 2       2023-08-02 12:16:55
# 3       2023-08-02 12:27:50
# 4       2023-08-02 12:36:34
#                ...
# 1196    2023-10-20 07:58:43
# 1197    2023-10-20 07:58:43
# 1198    2023-10-20 07:58:43
# 1199    2023-10-20 10:36:00
# 1200    2023-10-20 10:44:44
# Name: createdAt, Length: 1201, dtype: object

# %%
df["updatedAt"]=df["updatedAt"].str.get('$date')
df["updatedAt"]=df["updatedAt"].str.get('$numberLong')
df['updatedAt'] = pd.to_datetime(df['updatedAt'], unit='ms').dt.strftime('%Y-%m-%d %H:%M:%S')
df['updatedAt']
# Out:
# C:\Users\ajesh\AppData\Local\Temp\ipykernel_3364\3807022930.py:3: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   df['updatedAt'] = pd.to_datetime(df['updatedAt'], unit='ms').dt.strftime('%Y-%m-%d %H:%M:%S')
# 0       2023-08-02 11:04:49
# 1       2023-08-02 11:07:00
# 2       2023-08-02 12:16:55
# 3       2023-08-02 12:27:50
# 4       2023-08-02 12:36:34
#                ...
# 1196    2023-10-20 08:00:54
# 1197    2023-10-20 08:00:54
# 1198    2023-10-20 08:00:54
# 1199    2023-10-20 10:36:00
# 1200    2023-10-20 10:44:44
# Name: updatedAt, Length: 1201, dtype: object

# %%
df["pure"]
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#         ...
# 1196     True
# 1197     True
# 1198     True
# 1199    False
# 1200    False
# Name: pure, Length: 1201, dtype: bool
